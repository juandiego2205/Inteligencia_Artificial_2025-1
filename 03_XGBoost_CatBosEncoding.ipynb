# %% [markdown]
# ##**Instaladores**

# %%
# !pip install pandas scikit-learn matplotlib seaborn >nul 2>&1
# !pip install catboost >nul 2>&1

# %%
# !pip install optuna >nul 2>&1

# %% [markdown]
# ##**Librerias**

# %%
import pandas as pd
import numpy as np
from google.colab import drive
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from catboost import CatBoostClassifier
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.base import BaseEstimator, ClassifierMixin
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
import xgboost as xgb
drive.mount('/content/drive')
pd.set_option('display.max_columns', None)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**Funciones**

# %%
#Tabla resumen
def resumen(dataframe):
  # Cálculos de resumen
  null_counts = dataframe.isnull().sum()
  total_counts = len(dataframe)
  non_null_counts = dataframe.notnull().sum()
  data_types = dataframe.dtypes
  unique_counts = dataframe.nunique()
  # Crear DataFrame de resumen
  summary_df = pd.DataFrame({
      'Tipo de Dato': data_types,
      'Valores Únicos': unique_counts,
      'No Nulos': non_null_counts,
      'Nulos': null_counts,
      '% Nulos': (null_counts / total_counts) * 100
  })
  # Ordenar por % de nulos
  summary_df = summary_df.sort_values(by='% Nulos', ascending=False)
  # Aplicar formato con Styler
  styled_summary = summary_df.style \
      .format({'% Nulos': '{:.2f}%'}) \
      .bar(subset='% Nulos', color='#f08080') \
      .set_properties(**{'text-align': 'center'}) \
      .set_caption("Resumen de Columnas del DataFrame") \
      .set_table_styles([
          # Color del encabezado de columnas
          {'selector': 'th', 'props': [
              ('text-align', 'center'),
              ('background-color', '#1f4e79'),
              ('color', 'white'),
              ('font-weight', 'bold')
          ]},
          # Color de las celdas
          {'selector': 'td', 'props': [('padding', '5px')]},
          # Estilo del título de la tabla
          {'selector': 'caption', 'props': [
              ('color', '#1f4e79'),
              ('font-size', '18px'),
              ('text-align', 'center'),
              ('font-weight', 'bold')
          ]}
      ])
  # Mostrar
  display(styled_summary)
  # Información final
  print(f"\n🧾 El DataFrame tiene un total de **{len(dataframe.columns)}** columnas y **{len(dataframe)}** filas.")

# %%
#Función Encabezado
def encabezado(dataframe,filas=5):
  salida=dataframe.head(filas).style \
      .set_properties(**{
          'background-color': '#f9f9f9',
          'border': '1px solid #ddd',
          'text-align': 'center'
      }) \
      .set_table_styles([
          {'selector': 'th', 'props': [('background-color', '#4B8BBE'), ('color', 'white'), ('text-align', 'center')]}
      ]) \
      .highlight_null() \
      .set_caption("🔍 Vista Previa de los Primeros Registros")
  display(salida)

# %% [markdown]
# ##**Cargar Datos**

# %%
X_train = pd.read_csv('/content/drive/MyDrive/X_train.csv')
Y_train = pd.read_csv('/content/drive/MyDrive/y_train.csv')
X_test = pd.read_csv('/content/drive/MyDrive/X_test.csv')
id_test = pd.read_csv('/content/drive/MyDrive/id_test.csv')

# %%
resumen(X_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:4040: RuntimeWarning: invalid value encountered in scalar divide
#   end = (x - left) / (right - left)
# <style type="text/css">
# #T_a1181 th {
#   text-align: center;
#   background-color: #1f4e79;
#   color: white;
#   font-weight: bold;
# }
# #T_a1181 td {
#   padding: 5px;
# }
# #T_a1181 caption {
#   color: #1f4e79;
#   font-size: 18px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_a1181_row0_col0, #T_a1181_row0_col1, #T_a1181_row0_col2, #T_a1181_row0_col3, #T_a1181_row1_col0, #T_a1181_row1_col1, #T_a1181_row1_col2, #T_a1181_row1_col3, #T_a1181_row2_col0, #T_a1181_row2_col1, #T_a1181_row2_col2, #T_a1181_row2_col3, #T_a1181_row3_col0, #T_a1181_row3_col1, #T_a1181_row3_col2, #T_a1181_row3_col3, #T_a1181_row4_col0, #T_a1181_row4_col1, #T_a1181_row4_col2, #T_a1181_row4_col3, #T_a1181_row5_col0, #T_a1181_row5_col1, #T_a1181_row5_col2, #T_a1181_row5_col3, #T_a1181_row6_col0, #T_a1181_row6_col1, #T_a1181_row6_col2, #T_a1181_row6_col3, #T_a1181_row7_col0, #T_a1181_row7_col1, #T_a1181_row7_col2, #T_a1181_row7_col3, #T_a1181_row8_col0, #T_a1181_row8_col1, #T_a1181_row8_col2, #T_a1181_row8_col3, #T_a1181_row9_col0, #T_a1181_row9_col1, #T_a1181_row9_col2, #T_a1181_row9_col3, #T_a1181_row10_col0, #T_a1181_row10_col1, #T_a1181_row10_col2, #T_a1181_row10_col3, #T_a1181_row11_col0, #T_a1181_row11_col1, #T_a1181_row11_col2, #T_a1181_row11_col3, #T_a1181_row12_col0, #T_a1181_row12_col1, #T_a1181_row12_col2, #T_a1181_row12_col3, #T_a1181_row13_col0, #T_a1181_row13_col1, #T_a1181_row13_col2, #T_a1181_row13_col3, #T_a1181_row14_col0, #T_a1181_row14_col1, #T_a1181_row14_col2, #T_a1181_row14_col3, #T_a1181_row15_col0, #T_a1181_row15_col1, #T_a1181_row15_col2, #T_a1181_row15_col3, #T_a1181_row16_col0, #T_a1181_row16_col1, #T_a1181_row16_col2, #T_a1181_row16_col3, #T_a1181_row17_col0, #T_a1181_row17_col1, #T_a1181_row17_col2, #T_a1181_row17_col3, #T_a1181_row18_col0, #T_a1181_row18_col1, #T_a1181_row18_col2, #T_a1181_row18_col3, #T_a1181_row19_col0, #T_a1181_row19_col1, #T_a1181_row19_col2, #T_a1181_row19_col3, #T_a1181_row20_col0, #T_a1181_row20_col1, #T_a1181_row20_col2, #T_a1181_row20_col3, #T_a1181_row21_col0, #T_a1181_row21_col1, #T_a1181_row21_col2, #T_a1181_row21_col3, #T_a1181_row22_col0, #T_a1181_row22_col1, #T_a1181_row22_col2, #T_a1181_row22_col3, #T_a1181_row23_col0, #T_a1181_row23_col1, #T_a1181_row23_col2, #T_a1181_row23_col3, #T_a1181_row24_col0, #T_a1181_row24_col1, #T_a1181_row24_col2, #T_a1181_row24_col3 {
#   text-align: center;
# }
# #T_a1181_row0_col4, #T_a1181_row1_col4, #T_a1181_row2_col4, #T_a1181_row3_col4, #T_a1181_row4_col4, #T_a1181_row5_col4, #T_a1181_row6_col4, #T_a1181_row7_col4, #T_a1181_row8_col4, #T_a1181_row9_col4, #T_a1181_row10_col4, #T_a1181_row11_col4, #T_a1181_row12_col4, #T_a1181_row13_col4, #T_a1181_row14_col4, #T_a1181_row15_col4, #T_a1181_row16_col4, #T_a1181_row17_col4, #T_a1181_row18_col4, #T_a1181_row19_col4, #T_a1181_row20_col4, #T_a1181_row21_col4, #T_a1181_row22_col4, #T_a1181_row23_col4, #T_a1181_row24_col4 {
#   width: 10em;
#   text-align: center;
# }
# </style>
# <table id="T_a1181" class="dataframe">
#   <caption>Resumen de Columnas del DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1181_level0_col0" class="col_heading level0 col0" >Tipo de Dato</th>
#       <th id="T_a1181_level0_col1" class="col_heading level0 col1" >Valores Únicos</th>
#       <th id="T_a1181_level0_col2" class="col_heading level0 col2" >No Nulos</th>
#       <th id="T_a1181_level0_col3" class="col_heading level0 col3" >Nulos</th>
#       <th id="T_a1181_level0_col4" class="col_heading level0 col4" >% Nulos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1181_level0_row0" class="row_heading level0 row0" >ESTU_PRGM_DEPARTAMENTO</th>
#       <td id="T_a1181_row0_col0" class="data row0 col0" >float64</td>
#       <td id="T_a1181_row0_col1" class="data row0 col1" >688698</td>
#       <td id="T_a1181_row0_col2" class="data row0 col2" >692500</td>
#       <td id="T_a1181_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a1181_row0_col4" class="data row0 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a1181_level0_row1" class="row_heading level0 row1" >ESTU_VALORMATRICULAUNIVERSIDAD</th>
#       <td id="T_a1181_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_a1181_row1_col1" class="data row1 col1" >692310</td>
#       <td id="T_a1181_row1_col2" class="data row1 col2" >692500</td>
#       <td id="T_a1181_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_a1181_row1_col4" class="data row1 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a1181_level0_row2" class="row_heading level0 row2" >ESTU_HORASSEMANATRABAJA</th>
#       <td id="T_a1181_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_a1181_row2_col1" class="data row2 col1" >692436</td>
#       <td id="T_a1181_row2_col2" class="data row2 col2" >692500</td>
#       <td id="T_a1181_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_a1181_row2_col4" class="data row2 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a1181_level0_row3" class="row_heading level0 row3" >FAMI_ESTRATOVIVIENDA</th>
#       <td id="T_a1181_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_a1181_row3_col1" class="data row3 col1" >692422</td>
#       <td id="T_a1181_row3_col2" class="data row3 col2" >692500</td>
#       <td id="T_a1181_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_a1181_row3_col4" class="data row3 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a1181_level0_row4" class="row_heading level0 row4" >FAMI_TIENEINTERNET</th>
#       <td id="T_a1181_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_a1181_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_a1181_row4_col2" class="data row4 col2" >692500</td>
#       <td id="T_a1181_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_a1181_row4_col4" class="data row4 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a1181_level0_row5" class="row_heading level0 row5" >FAMI_EDUCACIONPADRE</th>
#       <td id="T_a1181_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_a1181_row5_col1" class="data row5 col1" >692050</td>
#       <td id="T_a1181_row5_col2" class="data row5 col2" >692500</td>
#       <td id="T_a1181_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_a1181_row5_col4" class="data row5 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a1181_level0_row6" class="row_heading level0 row6" >FAMI_TIENELAVADORA</th>
#       <td id="T_a1181_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_a1181_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_a1181_row6_col2" class="data row6 col2" >692500</td>
#       <td id="T_a1181_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_a1181_row6_col4" class="data row6 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a1181_level0_row7" class="row_heading level0 row7" >FAMI_TIENEAUTOMOVIL</th>
#       <td id="T_a1181_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_a1181_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_a1181_row7_col2" class="data row7 col2" >692500</td>
#       <td id="T_a1181_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_a1181_row7_col4" class="data row7 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a1181_level0_row8" class="row_heading level0 row8" >ESTU_PAGOMATRICULAPROPIO</th>
#       <td id="T_a1181_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_a1181_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_a1181_row8_col2" class="data row8 col2" >692500</td>
#       <td id="T_a1181_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_a1181_row8_col4" class="data row8 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a1181_level0_row9" class="row_heading level0 row9" >FAMI_TIENECOMPUTADOR</th>
#       <td id="T_a1181_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_a1181_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_a1181_row9_col2" class="data row9 col2" >692500</td>
#       <td id="T_a1181_row9_col3" class="data row9 col3" >0</td>
#       <td id="T
col9, #T_27ad1_row4_col10, #T_27ad1_row4_col11, #T_27ad1_row4_col12, #T_27ad1_row4_col13, #T_27ad1_row4_col14, #T_27ad1_row4_col15, #T_27ad1_row4_col16, #T_27ad1_row4_col17, #T_27ad1_row4_col18, #T_27ad1_row4_col19, #T_27ad1_row4_col20, #T_27ad1_row4_col21, #T_27ad1_row4_col22, #T_27ad1_row4_col23, #T_27ad1_row4_col24 {
#   background-color: #f9f9f9;
#   border: 1px solid #ddd;
#   text-align: center;
# }
# </style>
# <table id="T_27ad1" class="dataframe">
#   <caption>🔍 Vista Previa de los Primeros Registros</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27ad1_level0_col0" class="col_heading level0 col0" >ESTU_PRGM_DEPARTAMENTO</th>
#       <th id="T_27ad1_level0_col1" class="col_heading level0 col1" >ESTU_VALORMATRICULAUNIVERSIDAD</th>
#       <th id="T_27ad1_level0_col2" class="col_heading level0 col2" >ESTU_HORASSEMANATRABAJA</th>
#       <th id="T_27ad1_level0_col3" class="col_heading level0 col3" >FAMI_ESTRATOVIVIENDA</th>
#       <th id="T_27ad1_level0_col4" class="col_heading level0 col4" >FAMI_TIENEINTERNET</th>
#       <th id="T_27ad1_level0_col5" class="col_heading level0 col5" >FAMI_EDUCACIONPADRE</th>
#       <th id="T_27ad1_level0_col6" class="col_heading level0 col6" >FAMI_TIENELAVADORA</th>
#       <th id="T_27ad1_level0_col7" class="col_heading level0 col7" >FAMI_TIENEAUTOMOVIL</th>
#       <th id="T_27ad1_level0_col8" class="col_heading level0 col8" >ESTU_PAGOMATRICULAPROPIO</th>
#       <th id="T_27ad1_level0_col9" class="col_heading level0 col9" >FAMI_TIENECOMPUTADOR</th>
#       <th id="T_27ad1_level0_col10" class="col_heading level0 col10" >FAMI_EDUCACIONMADRE</th>
#       <th id="T_27ad1_level0_col11" class="col_heading level0 col11" >coef_1</th>
#       <th id="T_27ad1_level0_col12" class="col_heading level0 col12" >coef_2</th>
#       <th id="T_27ad1_level0_col13" class="col_heading level0 col13" >coef_3</th>
#       <th id="T_27ad1_level0_col14" class="col_heading level0 col14" >coef_4</th>
#       <th id="T_27ad1_level0_col15" class="col_heading level0 col15" >EDUMADRE_DISCRIMINANTE</th>
#       <th id="T_27ad1_level0_col16" class="col_heading level0 col16" >EDUPADRE_DISCRIMINANTE</th>
#       <th id="T_27ad1_level0_col17" class="col_heading level0 col17" >GRUPO_DEPARTAMENTO</th>
#       <th id="T_27ad1_level0_col18" class="col_heading level0 col18" >ISE</th>
#       <th id="T_27ad1_level0_col19" class="col_heading level0 col19" >ESFUERZO_FAMILIAR</th>
#       <th id="T_27ad1_level0_col20" class="col_heading level0 col20" >ACCESO_TECNOLOGICO</th>
#       <th id="T_27ad1_level0_col21" class="col_heading level0 col21" >NIVEL_SOCIOFAMILIAR</th>
#       <th id="T_27ad1_level0_col22" class="col_heading level0 col22" >DESAJUSTE_ECONOMICO</th>
#       <th id="T_27ad1_level0_col23" class="col_heading level0 col23" >INCONGRUENCIA_ISE_MATRICULA</th>
#       <th id="T_27ad1_level0_col24" class="col_heading level0 col24" >ESFUERZO_NORM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27ad1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27ad1_row0_col0" class="data row0 col0" >1.491769</td>
#       <td id="T_27ad1_row0_col1" class="data row0 col1" >1.491769</td>
#       <td id="T_27ad1_row0_col2" class="data row0 col2" >1.491769</td>
#       <td id="T_27ad1_row0_col3" class="data row0 col3" >1.491769</td>
#       <td id="T_27ad1_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_27ad1_row0_col5" class="data row0 col5" >1.491769</td>
#       <td id="T_27ad1_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_27ad1_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_27ad1_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_27ad1_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_27ad1_row0_col10" class="data row0 col10" >1.491769</td>
#       <td id="T_27ad1_row0_col11" class="data row0 col11" >0.437002</td>
#       <td id="T_27ad1_row0_col12" class="data row0 col12" >-0.556223</td>
#       <td id="T_27ad1_row0_col13" class="data row0 col13" >0.813978</td>
#       <td id="T_27ad1_row0_col14" class="data row0 col14" >0.060296</td>
#       <td id="T_27ad1_row0_col15" class="data row0 col15" >1.491769</td>
#       <td id="T_27ad1_row0_col16" class="data row0 col16" >1.491769</td>
#       <td id="T_27ad1_row0_col17" class="data row0 col17" >1.491769</td>
#       <td id="T_27ad1_row0_col18" class="data row0 col18" >1.395273</td>
#       <td id="T_27ad1_row0_col19" class="data row0 col19" >0.320585</td>
#       <td id="T_27ad1_row0_col20" class="data row0 col20" >0.415248</td>
#       <td id="T_27ad1_row0_col21" class="data row0 col21" >1.130560</td>
#       <td id="T_27ad1_row0_col22" class="data row0 col22" >1.137621</td>
#       <td id="T_27ad1_row0_col23" class="data row0 col23" >-1.202997</td>
#       <td id="T_27ad1_row0_col24" class="data row0 col24" >-0.652458</td>
#     </tr>
#     <tr>
#       <th id="T_27ad1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27ad1_row1_col0" class="data row1 col0" >1.491769</td>
#       <td id="T_27ad1_row1_col1" class="data row1 col1" >1.491769</td>
#       <td id="T_27ad1_row1_col2" class="data row1 col2" >1.491769</td>
#       <td id="T_27ad1_row1_col3" class="data row1 col3" >1.745884</td>
#       <td id="T_27ad1_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_27ad1_row1_col5" class="data row1 col5" >1.491769</td>
#       <td id="T_27ad1_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_27ad1_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_27ad1_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_27ad1_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_27ad1_row1_col10" class="data row1 col10" >1.491769</td>
#       <td id="T_27ad1

# %%
resumen(X_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:4040: RuntimeWarning: invalid value encountered in scalar divide
#   end = (x - left) / (right - left)
# <style type="text/css">
# #T_a2ac3 th {
#   text-align: center;
#   background-color: #1f4e79;
#   color: white;
#   font-weight: bold;
# }
# #T_a2ac3 td {
#   padding: 5px;
# }
# #T_a2ac3 caption {
#   color: #1f4e79;
#   font-size: 18px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_a2ac3_row0_col0, #T_a2ac3_row0_col1, #T_a2ac3_row0_col2, #T_a2ac3_row0_col3, #T_a2ac3_row1_col0, #T_a2ac3_row1_col1, #T_a2ac3_row1_col2, #T_a2ac3_row1_col3, #T_a2ac3_row2_col0, #T_a2ac3_row2_col1, #T_a2ac3_row2_col2, #T_a2ac3_row2_col3, #T_a2ac3_row3_col0, #T_a2ac3_row3_col1, #T_a2ac3_row3_col2, #T_a2ac3_row3_col3, #T_a2ac3_row4_col0, #T_a2ac3_row4_col1, #T_a2ac3_row4_col2, #T_a2ac3_row4_col3, #T_a2ac3_row5_col0, #T_a2ac3_row5_col1, #T_a2ac3_row5_col2, #T_a2ac3_row5_col3, #T_a2ac3_row6_col0, #T_a2ac3_row6_col1, #T_a2ac3_row6_col2, #T_a2ac3_row6_col3, #T_a2ac3_row7_col0, #T_a2ac3_row7_col1, #T_a2ac3_row7_col2, #T_a2ac3_row7_col3, #T_a2ac3_row8_col0, #T_a2ac3_row8_col1, #T_a2ac3_row8_col2, #T_a2ac3_row8_col3, #T_a2ac3_row9_col0, #T_a2ac3_row9_col1, #T_a2ac3_row9_col2, #T_a2ac3_row9_col3, #T_a2ac3_row10_col0, #T_a2ac3_row10_col1, #T_a2ac3_row10_col2, #T_a2ac3_row10_col3, #T_a2ac3_row11_col0, #T_a2ac3_row11_col1, #T_a2ac3_row11_col2, #T_a2ac3_row11_col3, #T_a2ac3_row12_col0, #T_a2ac3_row12_col1, #T_a2ac3_row12_col2, #T_a2ac3_row12_col3, #T_a2ac3_row13_col0, #T_a2ac3_row13_col1, #T_a2ac3_row13_col2, #T_a2ac3_row13_col3, #T_a2ac3_row14_col0, #T_a2ac3_row14_col1, #T_a2ac3_row14_col2, #T_a2ac3_row14_col3, #T_a2ac3_row15_col0, #T_a2ac3_row15_col1, #T_a2ac3_row15_col2, #T_a2ac3_row15_col3, #T_a2ac3_row16_col0, #T_a2ac3_row16_col1, #T_a2ac3_row16_col2, #T_a2ac3_row16_col3, #T_a2ac3_row17_col0, #T_a2ac3_row17_col1, #T_a2ac3_row17_col2, #T_a2ac3_row17_col3, #T_a2ac3_row18_col0, #T_a2ac3_row18_col1, #T_a2ac3_row18_col2, #T_a2ac3_row18_col3, #T_a2ac3_row19_col0, #T_a2ac3_row19_col1, #T_a2ac3_row19_col2, #T_a2ac3_row19_col3, #T_a2ac3_row20_col0, #T_a2ac3_row20_col1, #T_a2ac3_row20_col2, #T_a2ac3_row20_col3, #T_a2ac3_row21_col0, #T_a2ac3_row21_col1, #T_a2ac3_row21_col2, #T_a2ac3_row21_col3, #T_a2ac3_row22_col0, #T_a2ac3_row22_col1, #T_a2ac3_row22_col2, #T_a2ac3_row22_col3, #T_a2ac3_row23_col0, #T_a2ac3_row23_col1, #T_a2ac3_row23_col2, #T_a2ac3_row23_col3, #T_a2ac3_row24_col0, #T_a2ac3_row24_col1, #T_a2ac3_row24_col2, #T_a2ac3_row24_col3 {
#   text-align: center;
# }
# #T_a2ac3_row0_col4, #T_a2ac3_row1_col4, #T_a2ac3_row2_col4, #T_a2ac3_row3_col4, #T_a2ac3_row4_col4, #T_a2ac3_row5_col4, #T_a2ac3_row6_col4, #T_a2ac3_row7_col4, #T_a2ac3_row8_col4, #T_a2ac3_row9_col4, #T_a2ac3_row10_col4, #T_a2ac3_row11_col4, #T_a2ac3_row12_col4, #T_a2ac3_row13_col4, #T_a2ac3_row14_col4, #T_a2ac3_row15_col4, #T_a2ac3_row16_col4, #T_a2ac3_row17_col4, #T_a2ac3_row18_col4, #T_a2ac3_row19_col4, #T_a2ac3_row20_col4, #T_a2ac3_row21_col4, #T_a2ac3_row22_col4, #T_a2ac3_row23_col4, #T_a2ac3_row24_col4 {
#   width: 10em;
#   text-align: center;
# }
# </style>
# <table id="T_a2ac3" class="dataframe">
#   <caption>Resumen de Columnas del DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2ac3_level0_col0" class="col_heading level0 col0" >Tipo de Dato</th>
#       <th id="T_a2ac3_level0_col1" class="col_heading level0 col1" >Valores Únicos</th>
#       <th id="T_a2ac3_level0_col2" class="col_heading level0 col2" >No Nulos</th>
#       <th id="T_a2ac3_level0_col3" class="col_heading level0 col3" >Nulos</th>
#       <th id="T_a2ac3_level0_col4" class="col_heading level0 col4" >% Nulos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2ac3_level0_row0" class="row_heading level0 row0" >ESTU_PRGM_DEPARTAMENTO</th>
#       <td id="T_a2ac3_row0_col0" class="data row0 col0" >float64</td>
#       <td id="T_a2ac3_row0_col1" class="data row0 col1" >31</td>
#       <td id="T_a2ac3_row0_col2" class="data row0 col2" >296786</td>
#       <td id="T_a2ac3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a2ac3_row0_col4" class="data row0 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a2ac3_level0_row1" class="row_heading level0 row1" >ESTU_VALORMATRICULAUNIVERSIDAD</th>
#       <td id="T_a2ac3_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_a2ac3_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_a2ac3_row1_col2" class="data row1 col2" >296786</td>
#       <td id="T_a2ac3_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_a2ac3_row1_col4" class="data row1 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a2ac3_level0_row2" class="row_heading level0 row2" >ESTU_HORASSEMANATRABAJA</th>
#       <td id="T_a2ac3_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_a2ac3_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_a2ac3_row2_col2" class="data row2 col2" >296786</td>
#       <td id="T_a2ac3_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_a2ac3_row2_col4" class="data row2 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a2ac3_level0_row3" class="row_heading level0 row3" >FAMI_ESTRATOVIVIENDA</th>
#       <td id="T_a2ac3_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_a2ac3_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_a2ac3_row3_col2" class="data row3 col2" >296786</td>
#       <td id="T_a2ac3_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_a2ac3_row3_col4" class="data row3 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a2ac3_level0_row4" class="row_heading level0 row4" >FAMI_TIENEINTERNET</th>
#       <td id="T_a2ac3_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_a2ac3_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_a2ac3_row4_col2" class="data row4 col2" >296786</td>
#       <td id="T_a2ac3_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_a2ac3_row4_col4" class="data row4 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a2ac3_level0_row5" class="row_heading level0 row5" >FAMI_EDUCACIONPADRE</th>
#       <td id="T_a2ac3_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_a2ac3_row5_col1" class="data row5 col1" >12</td>
#       <td id="T_a2ac3_row5_col2" class="data row5 col2" >296786</td>
#       <td id="T_a2ac3_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_a2ac3_row5_col4" class="data row5 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a2ac3_level0_row6" class="row_heading level0 row6" >FAMI_TIENELAVADORA</th>
#       <td id="T_a2ac3_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_a2ac3_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_a2ac3_row6_col2" class="data row6 col2" >296786</td>
#       <td id="T_a2ac3_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_a2ac3_row6_col4" class="data row6 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a2ac3_level0_row7" class="row_heading level0 row7" >FAMI_TIENEAUTOMOVIL</th>
#       <td id="T_a2ac3_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_a2ac3_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_a2ac3_row7_col2" class="data row7 col2" >296786</td>
#       <td id="T_a2ac3_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_a2ac3_row7_col4" class="data row7 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a2ac3_level0_row8" class="row_heading level0 row8" >ESTU_PAGOMATRICULAPROPIO</th>
#       <td id="T_a2ac3_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_a2ac3_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_a2ac3_row8_col2" class="data row8 col2" >296786</td>
#       <td id="T_a2ac3_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_a2ac3_row8_col4" class="data row8 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a2ac3_level0_row9" class="row_heading level0 row9" >FAMI_TIENECOMPUTADOR</th>
#       <td id="T_a2ac3_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_a2ac3_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_a2ac3_row9_col2" class="data row9 col2" >296786</td>
#       <td id="T_a2ac3_row9_col3" class="data row9 col3" >0</td>
#       <td id="T
#   background-color: #f9f9f9;
#   border: 1px solid #ddd;
#   text-align: center;
# }
# </style>
# <table id="T_0cb13" class="dataframe">
#   <caption>🔍 Vista Previa de los Primeros Registros</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cb13_level0_col0" class="col_heading level0 col0" >ESTU_PRGM_DEPARTAMENTO</th>
#       <th id="T_0cb13_level0_col1" class="col_heading level0 col1" >ESTU_VALORMATRICULAUNIVERSIDAD</th>
#       <th id="T_0cb13_level0_col2" class="col_heading level0 col2" >ESTU_HORASSEMANATRABAJA</th>
#       <th id="T_0cb13_level0_col3" class="col_heading level0 col3" >FAMI_ESTRATOVIVIENDA</th>
#       <th id="T_0cb13_level0_col4" class="col_heading level0 col4" >FAMI_TIENEINTERNET</th>
#       <th id="T_0cb13_level0_col5" class="col_heading level0 col5" >FAMI_EDUCACIONPADRE</th>
#       <th id="T_0cb13_level0_col6" class="col_heading level0 col6" >FAMI_TIENELAVADORA</th>
#       <th id="T_0cb13_level0_col7" class="col_heading level0 col7" >FAMI_TIENEAUTOMOVIL</th>
#       <th id="T_0cb13_level0_col8" class="col_heading level0 col8" >ESTU_PAGOMATRICULAPROPIO</th>
#       <th id="T_0cb13_level0_col9" class="col_heading level0 col9" >FAMI_TIENECOMPUTADOR</th>
#       <th id="T_0cb13_level0_col10" class="col_heading level0 col10" >FAMI_EDUCACIONMADRE</th>
#       <th id="T_0cb13_level0_col11" class="col_heading level0 col11" >coef_1</th>
#       <th id="T_0cb13_level0_col12" class="col_heading level0 col12" >coef_2</th>
#       <th id="T_0cb13_level0_col13" class="col_heading level0 col13" >coef_3</th>
#       <th id="T_0cb13_level0_col14" class="col_heading level0 col14" >coef_4</th>
#       <th id="T_0cb13_level0_col15" class="col_heading level0 col15" >EDUMADRE_DISCRIMINANTE</th>
#       <th id="T_0cb13_level0_col16" class="col_heading level0 col16" >EDUPADRE_DISCRIMINANTE</th>
#       <th id="T_0cb13_level0_col17" class="col_heading level0 col17" >GRUPO_DEPARTAMENTO</th>
#       <th id="T_0cb13_level0_col18" class="col_heading level0 col18" >ACCESO_TECNOLOGICO</th>
#       <th id="T_0cb13_level0_col19" class="col_heading level0 col19" >ESFUERZO_FAMILIAR</th>
#       <th id="T_0cb13_level0_col20" class="col_heading level0 col20" >ISE</th>
#       <th id="T_0cb13_level0_col21" class="col_heading level0 col21" >NIVEL_SOCIOFAMILIAR</th>
#       <th id="T_0cb13_level0_col22" class="col_heading level0 col22" >DESAJUSTE_ECONOMICO</th>
#       <th id="T_0cb13_level0_col23" class="col_heading level0 col23" >INCONGRUENCIA_ISE_MATRICULA</th>
#       <th id="T_0cb13_level0_col24" class="col_heading level0 col24" >ESFUERZO_NORM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cb13_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cb13_row0_col0" class="data row0 col0" >1.576757</td>
#       <td id="T_0cb13_row0_col1" class="data row0 col1" >1.391822</td>
#       <td id="T_0cb13_row0_col2" class="data row0 col2" >1.396823</td>
#       <td id="T_0cb13_row0_col3" class="data row0 col3" >1.482493</td>
#       <td id="T_0cb13_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_0cb13_row0_col5" class="data row0 col5" >1.453422</td>
#       <td id="T_0cb13_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_0cb13_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_0cb13_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_0cb13_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_0cb13_row0_col10" class="data row0 col10" >1.674290</td>
#       <td id="T_0cb13_row0_col11" class="data row0 col11" >0.492496</td>
#       <td id="T_0cb13_row0_col12" class="data row0 col12" >-0.433304</td>
#       <td id="T_0cb13_row0_col13" class="data row0 col13" >0.907947</td>
#       <td id="T_0cb13_row0_col14" class="data row0 col14" >-0.228590</td>
#       <td id="T_0cb13_row0_col15" class="data row0 col15" >1.674290</td>
#       <td id="T_0cb13_row0_col16" class="data row0 col16" >1.517896</td>
#       <td id="T_0cb13_row0_col17" class="data row0 col17" >1.579579</td>
#       <td id="T_0cb13_row0_col18" class="data row0 col18" >0.366753</td>
#       <td id="T_0cb13_row0_col19" class="data row0 col19" >-1.463543</td>
#       <td id="T_0cb13_row0_col20" class="data row0 col20" >-0.384764</td>
#       <td id="T_0cb13_row0_col21" class="data row0 col21" >0.022671</td>
#       <td id="T_0cb13_row0_col22" class="data row0 col22" >-1.535605</td>
#       <td id="T_0cb13_row0_col23" class="data row0 col23" >0.014923</td>
#       <td id="T_0cb13_row0_col24" class="data row0 col24" >-0.961952</td>
#     </tr>
#     <tr>
#       <th id="T_0cb13_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0cb13_row1_col0" class="data row1 col0" >1.407371</td>
#       <td id="T_0cb13_row1_col1" class="data row1 col1" >1.678276</td>
#       <td id="T_0cb13_row1_col2" class="data row1 col2" >1.547282</td>
#       <td id="T_0cb13_row1_col3" class="data row1 col3" >1.609556</td>
#       <td id="T_0cb13_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_0cb13_row1_col5" class="data row1 col5" >1.548989</td>
#       <td id="T_0cb13_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_0cb13_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_0cb13_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_0cb13_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_0cb13_row1_col10" class="data row1 col10" >1.451805</td>
#       <td id="T_0c

# %%
encabezado(Y_train)
# Out:
# <style type="text/css">
# #T_f9cff th {
#   background-color: #4B8BBE;
#   color: white;
#   text-align: center;
# }
# #T_f9cff_row0_col0, #T_f9cff_row1_col0, #T_f9cff_row2_col0, #T_f9cff_row3_col0, #T_f9cff_row4_col0 {
#   background-color: #f9f9f9;
#   border: 1px solid #ddd;
#   text-align: center;
# }
# </style>
# <table id="T_f9cff" class="dataframe">
#   <caption>🔍 Vista Previa de los Primeros Registros</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9cff_level0_col0" class="col_heading level0 col0" >RENDIMIENTO_GLOBAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9cff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9cff_row0_col0" class="data row0 col0" >medio-alto</td>
#     </tr>
#     <tr>
#       <th id="T_f9cff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9cff_row1_col0" class="data row1 col0" >bajo</td>
#     </tr>
#     <tr>
#       <th id="T_f9cff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9cff_row2_col0" class="data row2 col0" >bajo</td>
#     </tr>
#     <tr>
#       <th id="T_f9cff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f9cff_row3_col0" class="data row3 col0" >alto</td>
#     </tr>
#     <tr>
#       <th id="T_f9cff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f9cff_row4_col0" class="data row4 col0" >medio-bajo</td>
#     </tr>
#   </tbody>
# </table>

# %%
#COdificacion Ordinal, importante para el tipo de modelo ordinal
ordinal_Y={
    'alto':3,
    'medio-alto':2,
    'medio-bajo':1,
    'bajo':0
}
Y_train['RENDIMIENTO_GLOBAL']=Y_train['RENDIMIENTO_GLOBAL'].map(ordinal_Y)

# %%
encabezado(Y_train)
# Out:
# <style type="text/css">
# #T_a8c52 th {
#   background-color: #4B8BBE;
#   color: white;
#   text-align: center;
# }
# #T_a8c52_row0_col0, #T_a8c52_row1_col0, #T_a8c52_row2_col0, #T_a8c52_row3_col0, #T_a8c52_row4_col0 {
#   background-color: #f9f9f9;
#   border: 1px solid #ddd;
#   text-align: center;
# }
# </style>
# <table id="T_a8c52" class="dataframe">
#   <caption>🔍 Vista Previa de los Primeros Registros</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8c52_level0_col0" class="col_heading level0 col0" >RENDIMIENTO_GLOBAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8c52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8c52_row0_col0" class="data row0 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a8c52_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8c52_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a8c52_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8c52_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a8c52_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8c52_row3_col0" class="data row3 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a8c52_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8c52_row4_col0" class="data row4 col0" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
resumen(Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:4040: RuntimeWarning: invalid value encountered in scalar divide
#   end = (x - left) / (right - left)
# <style type="text/css">
# #T_cb42a th {
#   text-align: center;
#   background-color: #1f4e79;
#   color: white;
#   font-weight: bold;
# }
# #T_cb42a td {
#   padding: 5px;
# }
# #T_cb42a caption {
#   color: #1f4e79;
#   font-size: 18px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_cb42a_row0_col0, #T_cb42a_row0_col1, #T_cb42a_row0_col2, #T_cb42a_row0_col3 {
#   text-align: center;
# }
# #T_cb42a_row0_col4 {
#   width: 10em;
#   text-align: center;
# }
# </style>
# <table id="T_cb42a" class="dataframe">
#   <caption>Resumen de Columnas del DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb42a_level0_col0" class="col_heading level0 col0" >Tipo de Dato</th>
#       <th id="T_cb42a_level0_col1" class="col_heading level0 col1" >Valores Únicos</th>
#       <th id="T_cb42a_level0_col2" class="col_heading level0 col2" >No Nulos</th>
#       <th id="T_cb42a_level0_col3" class="col_heading level0 col3" >Nulos</th>
#       <th id="T_cb42a_level0_col4" class="col_heading level0 col4" >% Nulos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb42a_level0_row0" class="row_heading level0 row0" >RENDIMIENTO_GLOBAL</th>
#       <td id="T_cb42a_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_cb42a_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_cb42a_row0_col2" class="data row0 col2" >692500</td>
#       <td id="T_cb42a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cb42a_row0_col4" class="data row0 col4" >0.00%</td>
#     </tr>
#   </tbody>
# </table>
# 🧾 El DataFrame tiene un total de **1** columnas y **692500** filas.

# %%
x_train, x_val, y_train, y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42, stratify=Y_train)

# %% [markdown]
# ##**Modelos**

# %% [markdown]
# ###**Fase 1**

# %%
def objective(trial):
    # Diccionario de hiperparámetros a optimizar
    params = {
        'objective': 'multi:softmax',      # Clasificación multiclase (predice directamente la clase con mayor probabilidad)
        'num_class': 4,                    # Número de clases en el target (en tu caso: 4 niveles de rendimiento)
        'tree_method': 'gpu_hist',         # Usar GPU para acelerar el entrenamiento
        'predictor': 'gpu_predictor',      # También usar GPU para las predicciones

        # Hiperparámetros a optimizar con Optuna:
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.15, log=True),  # Tasa de aprendizaje (más baja = mejor generalización)
        'max_depth': trial.suggest_int('max_depth', 7, 14),                           # Profundidad máxima de los árboles
        'n_estimators': trial.suggest_int('n_estimators', 1000, 3000),                # Número total de árboles (más = más potencia)

        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),             # Mínimo de datos por hoja (más alto = menos overfitting)
        'gamma': trial.suggest_float('gamma', 0, 5),                                  # Ganancia mínima para hacer una división (regulariza)
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),                      # Porcentaje de datos usados por árbol
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),        # Porcentaje de features usadas por árbol

        'lambda': trial.suggest_float('lambda', 0.01, 10.0, log=True),                # Regularización L2
        'alpha': trial.suggest_float('alpha', 0.01, 10.0, log=True),                  # Regularización L1

        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.8, 1.2),        # Balanceo de clases, cercano a 1 si no están desbalanceadas

        'eval_metric': 'mlogloss',               # Métrica para multiclase (pérdida logarítmica)
        'verbosity': 0,                          # No mostrar logs de entrenamiento
        'early_stopping_rounds': 50,             # Detener entrenamiento si no mejora en 50 rounds
        'random_state': 42,                      # Reproducibilidad
        'disable_default_eval_metric': True      # Solo usar la métrica personalizada (mlogloss)
    }

    # Entrenar modelo con los parámetros actuales
    model = xgb.XGBClassifier(**params)
    model.fit(x_train, y_train, eval_set=[(x_val, y_val)], verbose=False)

    # Evaluar el modelo
    preds = model.predict(x_val)
    acc = accuracy_score(y_val, preds)
    return acc
# Out:
# [I 2025-07-02 18:11:25,752] A new study created in memory with name: no-name-ba753ce6-2580-42b9-8d58-ad401f160e40
# [I 2025-07-02 18:12:11,984] Trial 0 finished with value: 0.4225270758122744 and parameters: {'learning_rate': 0.018044870641697953, 'max_depth': 8, 'n_estimators': 2654, 'min_child_weight': 9, 'gamma': 2.7151200411316245, 'subsample': 0.772203608344223, 'colsample_bytree': 0.7101415586740398, 'lambda': 2.3432413548517586, 'alpha': 0.021588506942800633, 'scale_pos_weight': 0.9586504024183446}. Best is trial 0 with value: 0.4225270758122744.
# [I 2025-07-02 18:12:51,159] Trial 1 finished with value: 0.42313357400722024 and parameters: {'learning_rate': 0.028542261527164714, 'max_depth': 12, 'n_estimators': 1095, 'min_child_weight': 9, 'gamma': 1.860937306224311, 'subsample': 0.834485703907346, 'colsample_bytree': 0.7460321836054405, 'lambda': 9.530080828082307, 'alpha': 0.01104146392643576, 'scale_pos_weight': 0.8526756473686905}. Best is trial 1 with value: 0.42313357400722024.
# [I 2025-07-02 18:13:43,978] Trial 2 finished with value: 0.423985559566787 and parameters: {'learning_rate': 0.01493995643742895, 'max_depth': 12, 'n_estimators': 1854, 'min_child_weight': 3, 'gamma': 3.18425328624007, 'subsample': 0.6872863533240899, 'colsample_bytree': 0.90728851715556, 'lambda': 2.1396031680264214, 'alpha': 0.022106389868621488, 'scale_pos_weight': 0.9838643811664352}. Best is trial 2 with value: 0.423985559566787.
# [I 2025-07-02 18:15:06,249] Trial 3 finished with value: 0.42187003610108303 and parameters: {'learning_rate': 0.01876409348171344, 'max_depth': 14, 'n_estimators': 1575, 'min_child_weight': 9, 'gamma': 1.4816488782185462, 'subsample': 0.8023920855208506, 'colsample_bytree': 0.6601537754511752, 'lambda': 0.7759293615643429, 'alpha': 0.018224053299000672, 'scale_pos_weight': 1.1618195619548304}. Best is trial 2 with value: 0.423985559566787.
# [I 2025-07-02 18:15:40,949] Trial 4 finished with value: 0.42296028880866426 and parameters: {'learning_rate': 0.026002025714864683, 'max_depth': 10, 'n_estimators': 2720, 'min_child_weight': 8, 'gamma': 1.2938814681742232, 'subsample': 0.6957476670508069, 'colsample_bytree': 0.6295397450066541, 'lambda': 3.364762958083153, 'alpha': 0.13200715821148784, 'scale_pos_weight': 1.1615519103601113}. Best is trial 2 with value: 0.423985559566787.
# [I 2025-07-02 18:15:50,839] Trial 5 finished with value: 0.4208880866425993 and parameters: {'learning_rate': 0.10080531584184452, 'max_depth': 7, 'n_estimators': 1467, 'min_child_weight': 6, 'gamma': 2.1856591356761976, 'subsample': 0.6223444372583623, 'colsample_bytree': 0.9319708362036907, 'lambda': 0.01155577823319942, 'alpha': 0.02260099473606063, 'scale_pos_weight': 0.9850721351980477}. Best is trial 2 with value: 0.423985559566787.
# [I 2025-07-02 18:16:43,109] Trial 6 finished with value: 0.423927797833935 and parameters: {'learning_rate': 0.014004599578552024, 'max_depth': 14, 'n_estimators': 2195, 'min_child_weight': 2, 'gamma': 2.6016427837718945, 'subsample': 0.8338743295171394, 'colsample_bytree': 0.6663086748575943, 'lambda': 1.1424343843559848, 'alpha': 7.636200524320706, 'scale_pos_weight': 0.9595855847405644}. Best is trial 2 with value: 0.423985559566787.
# [I 2025-07-02 18:16:58,481] Trial 7 finished with value: 0.4225848375451264 and parameters: {'learning_rate': 0.07827331758375364, 'max_depth': 12, 'n_estimators': 1673, 'min_child_weight': 7, 'gamma': 2.806152196459697, 'subsample': 0.6500481500202626, 'colsample_bytree': 0.9978253342077316, 'lambda': 0.5028247109571572, 'alpha': 1.2695201648089542, 'scale_pos_weight': 0.8844289181863757}. Best is trial 2 with value: 0.423985559566787.
# [I 2025-07-02 18:17:29,617] Trial 8 finished with value: 0.4242454873646209 and parameters: {'learning_rate': 0.023371252973849826, 'max_depth': 13, 'n_estimators': 1975, 'min_child_weight': 4, 'gamma': 3.5343802900294925, 'subsample': 0.9225154760484817, 'colsample_bytree': 0.8140645373468, 'lambda': 0.02126105525426635, 'alpha': 6.182468981150766, 'scale_pos_weight': 1.0359983557537344}. Best is trial 8 with value: 0.4242454873646209.
# [I 2025-07-02 18:17:49,278] Trial 9 finished with value: 0.42173285198555954 and parameters: {'learning_rate': 0.03980230740090046, 'max_depth': 8, 'n_estimators': 1600, 'min_child_weight': 10, 'gamma': 1.5585991189326143, 'subsample': 0.6506026480052356, 'colsample_bytree': 0.8059465361671118, 'lambda': 0.011949729827280485, 'alpha': 0.08783404044984798, 'scale_pos_weight': 0.9600494835678202}. Best is trial 8 with value: 0.4242454873646209.
# [I 2025-07-02 18:17:59,761] Trial 10 finished with value: 0.42132851985559566 and parameters: {'learning_rate': 0.06785553272458356, 'max_depth': 10, 'n_estimators': 2273, 'min_child_weight': 4, 'gamma': 4.635373502344237, 'subsample': 0.9849444854418342, 'colsample_bytree': 0.8257061520478315, 'lambda': 0.06365757121165491, 'alpha': 9.847355758228126, 'scale_pos_weight': 1.0721920357077515}. Best is trial 8 with value: 0.4242454873646209.
# [I 2025-07-02 18:18:54,741] Trial 11 finished with value: 0.4243898916967509 and parameters: {'learning_rate': 0.010421996349100201, 'max_depth': 12, 'n_estimators': 1987, 'min_child_weight': 3, 'gamma': 3.813475699006111, 'subsample': 0.9498218485499972, 'colsample_bytree': 0.8790613839374624, 'lambda': 0.1330844256878119, 'alpha': 1.2650640503917332, 'scale_pos_weight': 1.0553948253059982}. Best is trial 11 with value: 0.4243898916967509.
# [I 2025-07-02 18:19:43,777] Trial 12 finished with value: 0.4245848375451264 and parameters: {'learning_rate': 0.010921741927180933, 'max_depth': 13, 'n_estimators': 2152, 'min_child_weight': 1, 'gamma': 3.981505550449142, 'subsample': 0.9764898179849378, 'colsample_bytree': 0.867237822894555, 'lambda': 0.08940214783442055, 'alpha': 1.6997183310596244, 'scale_pos_weight': 1.059538599541387}. Best is trial 12 with value: 0.4245848375451264.
# [I 2025-07-02 18
. Best is trial 37 with value: 0.42468592057761734.
# [I 2025-07-02 18:46:37,988] Trial 45 finished with value: 0.4228447653429603 and parameters: {'learning_rate': 0.018787485619738076, 'max_depth': 14, 'n_estimators': 2243, 'min_child_weight': 9, 'gamma': 1.7251012382885678, 'subsample': 0.9662148940424823, 'colsample_bytree': 0.6943133977056019, 'lambda': 1.0995005538396172, 'alpha': 0.029512618770373988, 'scale_pos_weight': 0.9683203037316226}. Best is trial 37 with value: 0.42468592057761734.
# [I 2025-07-02 18:48:28,390] Trial 46 finished with value: 0.4234584837545126 and parameters: {'learning_rate': 0.011167668102619474, 'max_depth': 12, 'n_estimators': 2861, 'min_child_weight': 7, 'gamma': 1.188395939608593, 'subsample': 0.864528790974611, 'colsample_bytree': 0.738821153227479, 'lambda': 5.377980574857442, 'alpha': 0.11618822162522281, 'scale_pos_weight': 1.0219969733949725}. Best is trial 37 with value: 0.42468592057761734.
# [I 2025-07-02 18:48:46,958] Trial 47 finished with value: 0.423884476534296 and parameters: {'learning_rate': 0.02500508133642623, 'max_depth': 13, 'n_estimators': 2534, 'min_child_weight': 6, 'gamma': 4.779151715982779, 'subsample': 0.9997707668305182, 'colsample_bytree': 0.8047524732387328, 'lambda': 0.5041536049689629, 'alpha': 0.07724002695025446, 'scale_pos_weight': 1.0552683924242001}. Best is trial 37 with value: 0.42468592057761734.
# [I 2025-07-02 18:49:06,019] Trial 48 finished with value: 0.4244043321299639 and parameters: {'learning_rate': 0.04496637762592193, 'max_depth': 14, 'n_estimators': 2679, 'min_child_weight': 9, 'gamma': 3.4324940230480427, 'subsample': 0.9009250920640441, 'colsample_bytree': 0.8223734893248156, 'lambda': 0.3456321077974493, 'alpha': 0.0858537915480727, 'scale_pos_weight': 1.0769175392961134}. Best is trial 37 with value: 0.42468592057761734.
# [I 2025-07-02 18:49:48,673] Trial 49 finished with value: 0.42336462093862814 and parameters: {'learning_rate': 0.013746934753163144, 'max_depth': 9, 'n_estimators': 2383, 'min_child_weight': 7, 'gamma': 2.705749814380378, 'subsample': 0.9433825438083129, 'colsample_bytree': 0.902238416178982, 'lambda': 1.8282151322062163, 'alpha': 0.3931327369403942, 'scale_pos_weight': 1.1308122688878783}. Best is trial 37 with value: 0.42468592057761734.
# 🚀 Mejores hiperparámetros encontrados:
# {'learning_rate': 0.014078117522367692, 'max_depth': 13, 'n_estimators': 2409, 'min_child_weight': 8, 'gamma': 2.1019294258203285, 'subsample': 0.9823973280803207, 'colsample_bytree': 0.627330872741747, 'lambda': 1.3269292043998044, 'alpha': 0.3234236193934336, 'scale_pos_weight': 0.9838534387226989}
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:49:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(alpha=0.3234236193934336, base_score=None, booster=None,
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.627330872741747, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=2.1019294258203285,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, lambda=1.3269292043998044,
#               learning_rate=0.014078117522367692, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=13, max_leaves=None,
#               min_child_weight=8, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=2409, n_jobs=None, ...)

# %%
#Prediccion del modelo con datos de testeo
X_test = X_test[X_train.columns]
y_pred_xgboos = final_model.predict(X_test)

# %%
#Adjuntar el ID
id_test['RENDIMIENTO_GLOBAL'] =pd.Series(y_pred_xgboos)

# %%
Descodificacion ordinal
id_test['RENDIMIENTO_GLOBAL']=id_test['RENDIMIENTO_GLOBAL'].map({
    0:'bajo',
    1:'medio-bajo',
    2:'medio-alto',
    3:'alto'
})

# %%
resumen(id_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:4040: RuntimeWarning: invalid value encountered in scalar divide
#   end = (x - left) / (right - left)
# <style type="text/css">
# #T_fbedd th {
#   text-align: center;
#   background-color: #1f4e79;
#   color: white;
#   font-weight: bold;
# }
# #T_fbedd td {
#   padding: 5px;
# }
# #T_fbedd caption {
#   color: #1f4e79;
#   font-size: 18px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_fbedd_row0_col0, #T_fbedd_row0_col1, #T_fbedd_row0_col2, #T_fbedd_row0_col3, #T_fbedd_row1_col0, #T_fbedd_row1_col1, #T_fbedd_row1_col2, #T_fbedd_row1_col3 {
#   text-align: center;
# }
# #T_fbedd_row0_col4, #T_fbedd_row1_col4 {
#   width: 10em;
#   text-align: center;
# }
# </style>
# <table id="T_fbedd" class="dataframe">
#   <caption>Resumen de Columnas del DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbedd_level0_col0" class="col_heading level0 col0" >Tipo de Dato</th>
#       <th id="T_fbedd_level0_col1" class="col_heading level0 col1" >Valores Únicos</th>
#       <th id="T_fbedd_level0_col2" class="col_heading level0 col2" >No Nulos</th>
#       <th id="T_fbedd_level0_col3" class="col_heading level0 col3" >Nulos</th>
#       <th id="T_fbedd_level0_col4" class="col_heading level0 col4" >% Nulos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbedd_level0_row0" class="row_heading level0 row0" >ID</th>
#       <td id="T_fbedd_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_fbedd_row0_col1" class="data row0 col1" >296786</td>
#       <td id="T_fbedd_row0_col2" class="data row0 col2" >296786</td>
#       <td id="T_fbedd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fbedd_row0_col4" class="data row0 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_fbedd_level0_row1" class="row_heading level0 row1" >RENDIMIENTO_GLOBAL</th>
#       <td id="T_fbedd_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_fbedd_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_fbedd_row1_col2" class="data row1 col2" >296786</td>
#       <td id="T_fbedd_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_fbedd_row1_col4" class="data row1 col4" >0.00%</td>
#     </tr>
#   </tbody>
# </table>
# 🧾 El DataFrame tiene un total de **2** columnas y **296786** filas.

# %%
encabezado(id_test)
# Out:
# <style type="text/css">
# #T_b265d th {
#   background-color: #4B8BBE;
#   color: white;
#   text-align: center;
# }
# #T_b265d_row0_col0, #T_b265d_row0_col1, #T_b265d_row1_col0, #T_b265d_row1_col1, #T_b265d_row2_col0, #T_b265d_row2_col1, #T_b265d_row3_col0, #T_b265d_row3_col1, #T_b265d_row4_col0, #T_b265d_row4_col1 {
#   background-color: #f9f9f9;
#   border: 1px solid #ddd;
#   text-align: center;
# }
# </style>
# <table id="T_b265d" class="dataframe">
#   <caption>🔍 Vista Previa de los Primeros Registros</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b265d_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_b265d_level0_col1" class="col_heading level0 col1" >RENDIMIENTO_GLOBAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b265d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b265d_row0_col0" class="data row0 col0" >550236</td>
#       <td id="T_b265d_row0_col1" class="data row0 col1" >bajo</td>
#     </tr>
#     <tr>
#       <th id="T_b265d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b265d_row1_col0" class="data row1 col0" >98545</td>
#       <td id="T_b265d_row1_col1" class="data row1 col1" >medio-alto</td>
#     </tr>
#     <tr>
#       <th id="T_b265d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b265d_row2_col0" class="data row2 col0" >499179</td>
#       <td id="T_b265d_row2_col1" class="data row2 col1" >medio-bajo</td>
#     </tr>
#     <tr>
#       <th id="T_b265d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b265d_row3_col0" class="data row3 col0" >782980</td>
#       <td id="T_b265d_row3_col1" class="data row3 col1" >bajo</td>
#     </tr>
#     <tr>
#       <th id="T_b265d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b265d_row4_col0" class="data row4 col0" >785185</td>
#       <td id="T_b265d_row4_col1" class="data row4 col1" >bajo</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Guardar archivo CSV
id_test.to_csv('id_test.csv', index=False)
